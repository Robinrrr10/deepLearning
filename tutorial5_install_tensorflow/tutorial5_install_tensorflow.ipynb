# %% [markdown]
# ### Tutorial 5: Installation of tensor flow

# %%
import tensorflow

# %% [markdown]
# ###### After installing tensorflow. Above line should not give error when executing. Command to install tensorflow: pip install tensorflow
